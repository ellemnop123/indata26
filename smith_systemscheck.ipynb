# %% [markdown]
# # Systems Check
# ### Elle Smith
# ##### EMAT 62110
#
# I like
# * listing
# * things
# * like
# * this!
#
# *one asterisk italic* **two asterisks bold**

# %%
my_name = "Elle"
my_name
# Out:
# 'Elle'

# %%
def give_name():
    print(my_name)

give_name()
# Out:
# Elle

# %%
def return_name():
    return my_name

new_name = return_name()
new_name
