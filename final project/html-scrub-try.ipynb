# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
with open('world-folk-epics.html', encoding = 'utf-8') as html:
    epics = BeautifulSoup(html.read(), 'html.parser')

# %%
epics.main.ul.find_all('li')[0].text
# use the divs as a different section
# Out:
# 'Azərbaycanca'

# %%
epics.main.find_all('span', attrs = {'class': 'mw-heading mw-heading2'})
# Out:
# []
